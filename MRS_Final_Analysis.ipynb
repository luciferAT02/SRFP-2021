# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
import os
import laspec
from laspec import line_index
from scipy.constants import c
from scipy.signal import argrelextrema, peak_widths, find_peaks
from scipy.interpolate import UnivariateSpline
from laspec import normalization
import matplotlib.backends.backend_pdf as pdf

obj = '24_J062104.61+221010.1'
pdff = pdf.PdfPages("Final_MRS_Spectra_"+obj+".pdf")
path2 = '/home/luciferat02/Documents/SRFP_2021/MRS_LAMOST/Objects/'+obj
os.listdir(path2)
print(obj)
for spec_fp in os.listdir(path2):
    with fits.open(path2+'/'+spec_fp) as hdu:
        rband = hdu[2].data
    rflux = rband['FLUX']
    rwv = 10**(rband['LOGLAM'])
    range1 = len(rwv)
    num = 0
    l = 6560
    h = 6570
    r = normalization.normalize_spectrum_general(rwv,rflux, p=1e-6, q=0.1, niter = 100)
    r = np.array([r])
    for i in rwv:
        if i>=l and i<=h:
            num += 1
    fl = np.zeros(num)
    wl = np.zeros(num)
    j = 0
    for i in range(range1):
        if rwv[i]>=l and rwv[i]<=h:
            wl[j] = rwv[i]
            fl[j] = r[0][0][i]
            j += 1
    mean = sum(wl)/len(wl)
    var = sum((wl-mean)**2)/len(wl)
    sigma = np.sqrt(var)
    left = mean - 3*sigma
    right = mean + 3*sigma
    x = np.linspace(l, h, num)
    spline = UnivariateSpline(x, fl-np.max(fl)/2)
    print(spline.roots())
    i = np.argmax(fl)
    wav = wl[i]
    line_dict_info = {
                'line_center': wl[i],
                'line_range': (left,right),
                'line_shoulder_left': (left-0.2,left),
                'line_shoulder_right': (right,right+0.2)}
    EW = line_index.measure_line_index(rwv,r[0][0],flux_err=None, mask=None, 
                                   z=None, line_info = line_dict_info, num_refit=(100, None), 
                                   filepath=None, return_type='dict', verbose=False)
    E_W = EW['EW_int']

    if len(spline.roots())==2:
        print(spec_fp)
        print("Equivalent Width = ",EW['EW_int'])
        fig, ax1 = plt.subplots(1,1, figsize = [15,9])
        ax1.set_xlabel('Wavelength ($\AA$)',fontsize = 15)
        ax1.set_ylabel('Normalized Flux', fontsize = 15)
        ax1.set_title('H_alpha Profile of '+obj , fontsize = 15)
        ax1.set_xlim(6550,6580)
        r1, r2 = spline.roots()
        del_lambda = r2-r1
        lambda_halpha = wl[i]
        #denominator = 2*lambda_halpha*np.sqrt(np.log(2))
        #velocity = int(round((c*(del_lambda/denominator))/1000))
        velocity = int(round(((del_lambda/wav)*c)/1000))
        print("Velocity = ",velocity)
        ax1.plot(rwv,r[0][0])
        ax1.plot([left,right],[1,1],linewidth=0.5, c='r',label='EW =%.2f $\AA$'%E_W)
        ax1.plot([r1,r2],[np.max(fl)/2,np.max(fl)/2],linewidth=0.5, c='k',label='FWHM=%.2f $\AA$, vsin i=%d $kms^{-1}$'%(del_lambda,velocity))
        ax1.legend(loc='best')
        pdff.savefig(fig)
pdff.close()
# Out:
# 24_J062104.61+221010.1
# /home/luciferat02/.local/lib/python3.8/site-packages/laspec/normalization.py:206: RuntimeWarning: divide by zero encountered in true_divide
#   res1 = (res - np.percentile(res, 100 * q)) / stdres_interp
# /home/luciferat02/.local/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/luciferat02/.local/lib/python3.8/site-packages/numpy/core/_methods.py:194: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(
# /home/luciferat02/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# [6561.76901672 6567.62014754]
# med-58063-HIP29425K201_sp06-106.fits
# Equivalent Width =  -28.88423
# Velocity =  267
# ...

# %%
obj = '26_J060303.39+234737.3'
path2 = '/home/luciferat02/Documents/SRFP_2021/MRS_LAMOST/Objects/'+obj
os.listdir(path2)
for spec_fp in os.listdir(path2):
    with fits.open(path2+'/'+spec_fp) as hdu:
        rband = hdu[2].data
    rflux = rband['FLUX']
    rwv = 10**(rband['LOGLAM'])
    r = normalization.normalize_spectrum_general(rwv,rflux, p=1e-6, q=0.8, niter = 100)
    r = np.array([r])
    fig, ax1 = plt.subplots(1,1, figsize = [15,9])
    ax1.set_xlabel('Wavelength',fontsize = 15)
    ax1.set_xlim(6550,6580)
    ax1.set_ylabel('Relative Flux', fontsize = 15)
    ax1.set_title('H_alpha Profile of '+obj , fontsize = 15)
    #ax1.set_xlim(6560,6570)
    ax1.plot(rwv,r[0][0])
    fig.savefig('double.jpeg')
    break
# Out:
# /home/luciferat02/.local/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/luciferat02/.local/lib/python3.8/site-packages/numpy/core/_methods.py:194: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(
# /home/luciferat02/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)

# %%
from astropy.io import fits 
#import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#as pyfits
#raw_input = med-58062-HIP2811701_sp08-187.fits
with fits.open('/home/luciferat02/Documents/SRFP_2021/MRS_LAMOST/Objects/5_J061948.64+225524.6/med-58063-HIP29425K201_sp06-084.fits') as hdu:
#mrs_hdulist = pyfits.open(raw_input)

    bband = hdu[1].data
    rband = hdu[2].data
rflux = rband['FLUX']
rwv = 10**(rband['LOGLAM'])
bflux = bband['FLUX']
bwv = 10**(bband['LOGLAM'])
fig, (ax1,ax2) = plt.subplots(2,1,figsize=[15,9])
ax2.set_xlim(6650,6700)
ax1.plot(bwv,bflux)
ax2.plot(rwv,rflux)
plt.show()

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
import os
import laspec
from laspec import line_index
from scipy.constants import c
from scipy.signal import argrelextrema, peak_widths, find_peaks
from scipy.interpolate import UnivariateSpline
from laspec import normalization
import matplotlib.backends.backend_pdf as pdf

path = '/home/luciferat02/Documents/SRFP_2021/MRS_LAMOST/Objects'
os.listdir(path)
for obj in os.listdir(path):
    pdff = pdf.PdfPages("MRS_"+obj+".pdf")
    print(obj)
    for spec_fp in os.listdir(path2):
        with fits.open(path2+'/'+spec_fp) as hdu:
            rband = hdu[2].data
        rflux = rband['FLUX']
        rwv = 10**(rband['LOGLAM'])
        range1 = len(rwv)
        num = 0
        l = 6560
        h = 6570
        r = normalization.normalize_spectrum_general(rwv,rflux, p=1e-6, q=0.1, niter = 100)
        r = np.array([r])
        for i in rwv:
            if i>=l and i<=h:
                num += 1
        fl = np.zeros(num)
        wl = np.zeros(num)
        j = 0
        for i in range(range1):
            if rwv[i]>=l and rwv[i]<=h:
                wl[j] = rwv[i]
                fl[j] = r[0][0][i]
                j += 1
        mean = sum(wl)/len(wl)
        var = sum((wl-mean)**2)/len(wl)
        sigma = np.sqrt(var)
        left = mean - 3*sigma
        right = mean + 3*sigma
        x = np.linspace(l, h, num)
        spline = UnivariateSpline(x, fl-np.max(fl)/2)
        i = np.argmax(fl)
        wav = wl[i]
        line_dict_info = {
                'line_center': 6564,
                'line_range': (left,right),
                'line_shoulder_left': (left-0.25,left),
                'line_shoulder_right': (right,right+0.25)}
        EW = line_index.measure_line_index(rwv,r[0][0],flux_err=None, mask=None, 
                                   z=None, line_info = line_dict_info, num_refit=(100, None), 
                                   filepath=None, return_type='dict', verbose=False)
        E_W = EW['EW_int']

        if len(spline.roots())==2:
            print(spec_fp)
            print("Equivalent Width = ",EW['EW_int'])
            fig, ax1 = plt.subplots(1,1, figsize = [15,9])
            ax1.set_xlabel('Wavelength',fontsize = 15)
            ax1.set_ylabel('Normalized Flux', fontsize = 15)
            ax1.set_title('H_alpha Profile of '+obj , fontsize = 15)
            ax1.set_xlim(6550,6580)
            r1, r2 = spline.roots()
            del_lambda = r2-r1
            lambda_halpha = wl[i]
            #denominator = 2*lambda_halpha*np.sqrt(np.log(2))
            #velocity = int(round((c*(del_lambda/denominator))/1000))
            velocity = int(round(((del_lambda/wav)*c)/1000))
            print("Velocity = ",velocity)
            ax1.plot(rwv,r[0][0])
            ax1.plot([left,right],[1,1],linewidth=0.5, c='r',label='EW =%.2f $\AA$'%E_W)
            ax1.plot([r1,r2],[np.max(r[0][0])/2,np.max(r[0][0])/2],linewidth=0.5, c='k',label='FWHM=%.2f $\AA$, Vsin i=%d $kms^{-1}$'%(del_lambda,velocity))
            ax1.legend(loc='best')
            pdff.savefig(fig)
    pdff.close()
# Out:
# 23_J061149.08+224932.7
# /home/luciferat02/.local/lib/python3.8/site-packages/laspec/normalization.py:206: RuntimeWarning: divide by zero encountered in true_divide
#   res1 = (res - np.percentile(res, 100 * q)) / stdres_interp
# med-58063-HIP29425K201_sp06-106.fits
# Equivalent Width =  -29.00039
# Velocity =  267
# /home/luciferat02/.local/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/luciferat02/.local/lib/python3.8/site-packages/numpy/core/_methods.py:194: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(
# /home/luciferat02/.local/lib/python3.8/site-packages/numpy/core/_methods.py:226: RuntimeWarning: invalid value encountered in true_divide
#   ret = ret.dtype.type(ret / rcount)
# med-58122-HIP29425K201_sp06-106.fits
# Equivalent Width =  -29.34097
# Velocity =  265
# ...

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

AE = [49,50,51,45,45,51,46,58,49,65,41,42,98]
Ae = [59,45,48,31,41,59]
BE = [98,90,101,115,126,82,100,127,71,114,117,98,102,102,123,108,111,89,93,97,111,104,117,98,94,89,90,96]
Be = [391,403,405,395,408,391,397,398,393,394,267,265,264,266,264,264,284,264,265,267]

mean = np.zeros(4)
var = np.zeros(4)
sigma = np.zeros(4)

mean[0] = sum(AE)/len(AE)
var[0] = sum((AE-mean[0])**2)/len(AE)
sigma[0] = np.sqrt(var[0])

mean[1] = sum(Ae)/len(Ae)
var[1] = sum((Ae-mean[1])**2)/len(Ae)
sigma[1] = np.sqrt(var[1])

mean[2] = sum(BE)/len(BE)
var[2] = sum((BE-mean[2])**2)/len(BE)
sigma[2] = np.sqrt(var[2])

mean[3] = sum(Be)/len(Be)
var[3] = sum((Be-mean[3])**2)/len(Be)
sigma[3] = np.sqrt(var[3])
strin = ['A[e]','Ae','B[e]','Be']
print(mean)
print(sigma)
'''fig = plt.figure(figsize=(15, 9))
plt.errorbar(strin, mean, sigma, linestyle='None', marker='o', capsize=3, ecolor = 'r', ms = 8)
plt.title('Aggregate Plot of Projected Rotational Velocity vs Star Classification', fontsize = 20)
plt.xlabel('Star Classification', fontsize = 20)
plt.ylabel('V$~$sin i (kms$^{-1}$)', fontsize = 20 )
plt.savefig('vsinivsclass.jpeg')
plt.show()'''

df = pd.DataFrame([mean,sigma],columns = strin)
df.head()
ax = df.plot.box(figsize = (10,8),fontsize = 15)
ax.set_xlabel('Star Classification',fontsize = 15)
ax.set_ylabel('vsin i (km$s^{-1}$)',fontsize = 15)
ax.set_title('Box Plot of Projected Rotational Velocity vs Star Classification', fontsize = 15)
fig = ax.get_figure()
fig.savefig('starvsiniaggregate.jpeg')
# Out:
# [ 53.07692308  47.16666667 102.25       332.25      ]
# [14.37124018  9.87280215 13.16278575 65.50028626]

# %%
AE = [-8.97,-8.53,-6.94,-6.57,-19.75,-26.43,-5.79,-24.71,-19.22,-104.63,-1.23,-25.45,-48.83,-0.90]
Ae = [-19.00,-66.44,-22.02,-22.55,-77.29,-3.44]
BE = [-4.76,-5.57,-5.88,-4.35,-4.22,-6.69,-5.10,-4.06,-6.63,-4.43,-34.74,-89.11,-55.23,-77.85,-40.50,-48.39,-52.93,-57.28,-0.97,-0.90,-0.43,-0.64,-0.52,-2.47,-3.87,-4.77,-5.00,-3.73]
Be = [-13.65,-14.25,-14.00,-14.03,-13.54,-13.73,-13.86,-14.00,-13.54,-13.84,-28.88,-29.27,-30.03,-30.33,-30.05,-30.64,-21.78,-29.91,-30.12,-28.77]


mean = np.zeros(4)
var = np.zeros(4)
sigma = np.zeros(4)

mean[0] = sum(AE)/len(AE)
var[0] = sum((AE-mean[0])**2)/len(AE)
sigma[0] = np.sqrt(var[0])

mean[1] = sum(Ae)/len(Ae)
var[1] = sum((Ae-mean[1])**2)/len(Ae)
sigma[1] = np.sqrt(var[1])

mean[2] = sum(BE)/len(BE)
var[2] = sum((BE-mean[2])**2)/len(BE)
sigma[2] = np.sqrt(var[2])

mean[3] = sum(Be)/len(Be)
var[3] = sum((Be-mean[3])**2)/len(Be)
sigma[3] = np.sqrt(var[3])
strin = ['A[e]','Ae','B[e]','Be']
print(mean)
print(sigma)
'''fig = plt.figure(figsize=(15, 9))
plt.errorbar(strin, mean, sigma, linestyle='None', marker='o', capsize=3, ecolor = 'r', ms = 8)
plt.title('Aggregate Plot of Equivalent Width vs Star Classification', fontsize = 20)
plt.xlabel('Star Classification', fontsize = 20)
plt.ylabel('EW($\AA$)', fontsize = 20 )
plt.savefig('ewvsclass.jpeg')
plt.show()'''
df = pd.DataFrame([mean,sigma],columns = strin)
df.head()
ax = df.plot.box(figsize = (10,8),fontsize = 15)
ax.set_xlabel('Star Classification',fontsize = 15)
ax.set_ylabel('EW ($\AA$)',fontsize = 15)
ax.set_title('Box Plot of Equivalent Width vs Star Classification', fontsize = 15)
fig = ax.get_figure()
fig.savefig('starewaggregate.jpeg')
# Out:
# [-21.99642857 -35.12333333 -18.965      -21.411     ]
# [26.12429811 26.93307426 25.78291579  7.76737337]
